# %%
water_level=20
while water_level <50:
    print("irrigation ON-water level;",water_level,"%")
    water_level +=5
    print("sufficient water, Iriigation OFF,")
# Out:
# irrigation ON-water level; 20 %
# sufficient water, Iriigation OFF,
# irrigation ON-water level; 25 %
# sufficient water, Iriigation OFF,
# irrigation ON-water level; 30 %
# sufficient water, Iriigation OFF,
# irrigation ON-water level; 35 %
# sufficient water, Iriigation OFF,
# irrigation ON-water level; 40 %
# sufficient water, Iriigation OFF,
# irrigation ON-water level; 45 %
# sufficient water, Iriigation OFF,

# %%
count=1
while True:
  print(count)
  if count==5:
     break
  count +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count=0
while count <5:
    count +=1
    if count==3:
       continue
print(count)
# Out:
# 5

# %%
count=1
while count <=3:
     print(count)
     count +=1
else:
    print("loop completed successfully")
# Out:
# 1
# 2
# 3
# loop completed successfully

# %%
ph =float(input("Enter soil ph value: "))
if ph <0 or ph>14:
    print("invalid ph value")
elif ph <6.5:
    print("soil is acidic")
elif 6.5 <= ph <= 7.5:
    print("soil is neutral")
else:
    print("soil is alkaline")
# Out:
# Enter soil ph value: 4.6
# soil is acidic

# %%
#crop suitability check for rice
soil_moisture =float(input("enter soil moisture percentage: "))
rainfall =float(input("enter the rainfall in mm: "))
if soil_moisture >=70 and rainfall>=200:
  print("suitable for rice")
else:
  print("not suitable for rice")
# Out:
# enter soil moisture percentage: 70
# enter the rainfall in mm: 250
# suitable for rice

# %%
# fertiliger recomendation system

crop =input("enter crop name(rice/wheat/maize): ").strip().lower()
nitrogen =float(input("enter soil nitrogen level: "))
if crop=="rice" and nitrogen <50:
  print("apply urea")
elif crop=="wheat"and nitrogen <40:
    print("apply DAP")
else:
      print("no fertiliger recommendation needed")
# Out:
# enter crop name(rice/wheat/maize): maize
# enter soil nitrogen level: 80
# no fertiliger recommendation needed

# %%
#crop yield classification
crop_yield =float(input("enter crop yield in quantals: "))
if crop_yield >=50:
  print("Highg yield")

elif 30 <=crop_yield<= 49:
  print("medium yield")
elif crop_yield <30:
  print("low yield")
# Out:
# enter crop yield in quantals: 48
# medium yield

# %%
# irrigation scheduling
for i in range(5):
    print(f"{i} irrigation scheduling (number field):")
# Out:
# 0 irrigation scheduling (number field):
# 1 irrigation scheduling (number field):
# 2 irrigation scheduling (number field):
# 3 irrigation scheduling (number field):
# 4 irrigation scheduling (number field):

# %%
#crop list display
crops = ["Rice","Wheat","Maize","Millet"]
for crop_name in crops:
  print(crop_name)
crop_appended="sugarcane"
crops.append(crop_appended)
print(crop_appended)
# Out:
# Rice
# Wheat
# Maize
# Millet
# sugarcane

# %%
#crop availability check
crop_name = input("enter crop name").strip().lower()
if crop_name in ["rice","wheat","maize"]:
  print("crop available")
else:
  print("crop not available")
# Out:
# enter crop nameragi
# crop not available

# %%
#index() method
thislist=["apple","banana","cherry","banana"]
index_value=thislist.index("banana")
print("banana",index_value)
# Out:
# banana 1

# %%
#count() method
thislist=["apple","banana","apple","cherry","apple"]
count_value=thislist.count("apple")
print("count of apple:",count_value)
# Out:
# count of apple: 3

# %%
#reverse() method
thislist=["apple","orange","muskmelon","kiwi","mango","grapes"]
print("original list:",thislist)
thislist.reverse()
print("reveresd list:",thislist)
# Out:
# original list: ['apple', 'orange', 'muskmelon', 'kiwi', 'mango', 'grapes']
# reveresd list: ['grapes', 'mango', 'kiwi', 'muskmelon', 'orange', 'apple']

# %%
original_list=[1,2,3,4,5]
reversed_iterator=reversed(original_list)
reversed_list=list(reversed_iterator)
print(reversed_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
#list length
thislist=["aple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
#list items -data type
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["apple","banana","cherry"]
for item in range(len(list1)):
 print(list1[item])
# Out:
# apple
# banana
# cherry

# %%
#tupe()
x=10
y=11.5
mylist=["apple","banana","cherry"]
print(type(x))
print(type(y))
print(type(mylist))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'list'>

# %%
print(5&3)
# Out:
# 1

# %%
x=[1,2,3]
y=x
z=[1,2,3]
print(x is y,x is z)
# Out:
# True False

# %%
nums=[1,2,3,4,5]
i=0
while i<len(nums):
   if nums[i]%2==0:
      nums.pop(i)
else:
      i+=1
      print(nums)

# %%
nums=[1,2,3.4,5]
i=0
while i<len(nums)
   if nums[i]% 2==0
     nums.pop(i):
   else:
    i+=1
   print(nums)

# %%
lst=[1,2,3,]
for x in lst:
  lst.append(x)
  if len(lst)>4
     break
print(lst)

# %%
print(4<<2)

# %%
print(5^3)

# %%
i=0
while i<5:
  i+=1
  if i==3:
    continue
print(i,end="")

# %%
lst=[1,2,3,4]
for x in lst:
  if x%2==0:
    lst.remove(x)
print(lst)

# %%
i=0
while i<5:
  print(i)

# %%
# no arguments is passed
def number_of_crops():
  return 150
number_of_crops()
# Out:
# 150

# %%
#no argument is pased , no value is return
def weather_update():
  print("the weater today is sunny with no rain expected")
weather_update()
# Out:
# the weater today is sunny with no rain expected

# %%
#only one argument is passed,no value is return
def plant_info(plant_name):
    print(f"The {plant_name} requires at least 8 hours of sunlight.")
plant_info("snake tree")
# Out:
# The snake tree requires at least 8 hours of sunlight.

# %%
#only one argument is passed , value is return
def water_needs(plant_type):
    if plant_type =="corn":
       return 30
    elif plant_type =="wheat":
       return 20
    else:
       return 25
water_needs("wheat")
# Out:
# 20

# %%
#two arguments are passed ,value is needed
def total_yield(area,yield_per_acre):
    return area*yield_per_acre
total_yield(2,20)
# Out:
# 40

# %%
#Two arguments are passed, no value return
def irrigation_needed(moisture_level, rainfall):
   if moisture_level<=40 and rainfall<=10:
     print("irrigation needed")
   else:
     print("irrigation not needed")
irrigation_needed(40,10)
# Out:
# irrigation needed

# %%
def total_yield():
  area=int(input("enter the area"))
  yield_per_hectare=float(input("enter the yield per hectare"))
  calculated_yield=area*yield_per_hectare
  return calculated_yield

total_yield()
# Out:
# enter the area44
# enter the yield per hectare44
# 1936.0

# %%
def is_read_for_harvest(days_since_planted,plant_type):
  if days_since_planted >=120 and plant_type=="rice":
    return True
  else:
    return False
plant_type=input("enter plant type")
days_since_planted=int(input("enter days since planted"))
is_read_for_harvest(days_since_planted,plant_type)
# Out:
# enter plant typerice
# enter days since planted180
# True

# %%
def weather_condition():
  teperature=28 #in celsius
  humidity=70   #in percentage
  return teperature,humidity

#usage
temp,hum=weather_condition()
print(f"temperature:{temp} celsius")
print(f"humidity:{hum}%")
# Out:
# temperature:28 celsius
# humidity:70%
