# %%
import pandas as pd
import numpy as np
#Create sample dataframe
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5]
})
df.dropna()
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
df.dropna(axis=1)
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
df.dropna(how='all')
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
import pandas as pd
import numpy as np
#Create sample dataframe
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales','IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5]
})
df.isna()
# Out:
#     name  department  salary  experience
# 0  False       False   False       False
# 1  False       False   False       False
# 2  False       False   False       False
# 3  False       False   False       False

# %%
df.isnull()
# Out:
#     name  department  salary  experience
# 0  False       False   False       False
# 1  False       False   False       False
# 2  False       False   False       False
# 3  False       False   False       False

# %%
df.isna().sum()
# Out:
# name          0
# department    0
# salary        0
# experience    0
# dtype: int64

# %%
df.fillna(0)
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
df.ffill()
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
df.fillna({'col1':0,'col2':'unknown'})
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5
