# %%
import pandas as pd
import numpy as np
#Create sample dataframe
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5]
})
print(df)
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
#sort
sal = df.sort_values('salary')
print(sal)
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 2    Bob      Sales   15555           2
# 1   Jane  Marketing   23333           4
# 3  Alice         IT   25003           5

# %%
sal = df.sort_values('salary',ascending=False)
print(sal)
# Out:
#     name department  salary  experience
# 3  Alice         IT   25003           5
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 0   John      Sales   10000           1

# %%
sal = df.sort_values(['salary','experience'],ascending=[False,True])
print(sal)
# Out:
#     name department  salary  experience
# 3  Alice         IT   25003           5
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 0   John      Sales   10000           1

# %%
#sort of index
sal = df.sort_index(ascending = True)
print(sal)
# Out:
#     name department  salary  experience
# 0   John      Sales   10000           1
# 1   Jane  Marketing   23333           4
# 2    Bob      Sales   15555           2
# 3  Alice         IT   25003           5

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5],
    'rank_salary':[4,56,3,1],
    'dense_rank_salary' : [1,2,3,4]
})
df['rank_salary'] = df['salary'].rank()
print(df)
# Out:
#     name department  salary  experience  rank_salary  dense_rank_salary
# 0   John      Sales   10000           1          1.0                  1
# 1   Jane  Marketing   23333           4          3.0                  2
# 2    Bob      Sales   15555           2          2.0                  3
# 3  Alice         IT   25003           5          4.0                  4

# %%
df['rank_salary'] = df['salary'].rank(ascending=False)
print(df)
# Out:
#     name department  salary  experience  rank_salary  dense_rank_salary
# 0   John      Sales   10000           1          4.0                  1
# 1   Jane  Marketing   23333           4          2.0                  2
# 2    Bob      Sales   15555           2          3.0                  3
# 3  Alice         IT   25003           5          1.0                  4

# %%
df['dense_rank_salary'] = df['salary'].rank(method='dense')
print(df)
# Out:
#     name department  salary  experience  rank_salary  dense_rank_salary
# 0   John      Sales   10000           1          4.0                1.0
# 1   Jane  Marketing   23333           4          2.0                3.0
# 2    Bob      Sales   15555           2          3.0                2.0
# 3  Alice         IT   25003           5          1.0                4.0

# %%
#valur count
df = df['department'].value_counts()
print(df)
# Out:
# department
# Sales        2
# Marketing    1
# IT           1
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5],
    'rank_salary':[4,56,3,1],
    'dense_rank_salary' : [1,2,3,4]
})
df = df['department'].value_counts(normalize=True)
print(df)
# Out:
# department
# Sales        0.50
# Marketing    0.25
# IT           0.25
# Name: proportion, dtype: float64

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5],
    'rank_salary':[4,56,3,1],
    'dense_rank_salary' : [1,2,3,4]
})
df[['salary','experience']].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2094694467.py in <cell line: 0>()
#      10 })
#      11 df[['salary','experience']].plot()
# ---> 12 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df["salary"].plot(kind='hist',bins=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1333969821.py in <cell line: 0>()
#       1 df["salary"].plot(kind='hist',bins=5)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.plot(kind='bar',x='name',y='salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-396813703.py in <cell line: 0>()
#       1 df.plot(kind='bar',x='name',y='salary')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.plot(kind='scatter',x='experience',y='salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-43970425.py in <cell line: 0>()
#       1 df.plot(kind='scatter',x='experience',y='salary')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice'],
    'department': ['Sales', 'Marketing', 'Sales', 'IT'],
    'salary': [10000,23333,15555,25003],
    'experience':[1,4,2,5],
    'rank_salary':[4,56,3,1],
    'dense_rank_salary' : [1,2,3,4]
})
df["salary"].plot(kind='pie')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3123808981.py in <cell line: 0>()
#      10 })
#      11 df["salary"].plot(kind='pie')
# ---> 12 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df[['salary','experience']].plot(kind='box')
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-939273204.py in <cell line: 0>()
#       1 df[['salary','experience']].plot(kind='box')
# ----> 2 plt.show
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd

data = {
    'Farm_ID': ['F001', 'F002', 'F003', 'F004', 'F005', 'F006', 'F007'],
    'Crop': ['Wheat', 'Rice', 'Corn', 'Wheat', 'Rice', 'Corn', 'Wheat'],
    'Yield_tons': [180, 228, 416, 164, 245, 390, 195],
    'Rainfall_mm': [450, 820, 680, 420, 850, 710, 480],
    'Fertilizer_kg': [120, 150, 200, 110, 160, 195, 125],
    'Soil_pH': [6.5, 5.8, 6.2, 6.7, 5.9, 6.1, 6.4]
}

df = pd.DataFrame(data)
df['Yield_per_ha'] = (df['Yield_tons'] / 50).round(1)  # Assume 50 ha each

print('Original Dataset:')
print(df)
# Out:
# Original Dataset:
#   Farm_ID   Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH  \
# 0    F001  Wheat         180          450            120      6.5
# 1    F002   Rice         228          820            150      5.8
# 2    F003   Corn         416          680            200      6.2
# 3    F004  Wheat         164          420            110      6.7
# 4    F005   Rice         245          850            160      5.9
# 5    F006   Corn         390          710            195      6.1
# 6    F007  Wheat         195          480            125      6.4
#
#    Yield_per_ha
# 0           3.6
# 1           4.6
# 2           8.3
# 3           3.3
# 4           4.9
# 5           7.8
# 6           3.9

# %%
print('\n=== HIGH YIELD FARMS (>200 tons) ===')
high_yield = df[df['Yield_tons'] > 200]
print(high_yield)
# Out:
# === HIGH YIELD FARMS (>200 tons) ===
#   Farm_ID  Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH  Yield_per_ha
# 1    F002  Rice         228          820            150      5.8           4.6
# 2    F003  Corn         416          680            200      6.2           8.3
# 4    F005  Rice         245          850            160      5.9           4.9
# 5    F006  Corn         390          710            195      6.1           7.8

# %%
 print('\n=== RICE WITH HIGH RAINFALL (>800mm) ===')
rice_high_rain = df[(df['Crop'] == 'Rice') & (df['Rainfall_mm'] > 800)]
print(rice_high_rain)
# Out:
# === RICE WITH HIGH RAINFALL (>800mm) ===
#   Farm_ID  Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH  Yield_per_ha
# 1    F002  Rice         228          820            150      5.8           4.6
# 4    F005  Rice         245          850            160      5.9           4.9

# %%
 print('\n=== GRAIN CROPS (Wheat & Rice) ===')
grain_crops = df[df['Crop'].isin(['Wheat', 'Rice'])]
print(grain_crops[['Farm_ID', 'Crop', 'Yield_tons']])
# Out:
# === GRAIN CROPS (Wheat & Rice) ===
#   Farm_ID   Crop  Yield_tons
# 0    F001  Wheat         180
# 1    F002   Rice         228
# 3    F004  Wheat         164
# 4    F005   Rice         245
# 6    F007  Wheat         195

# %%
 print('\n=== OPTIMAL SOIL pH (6.0 to 6.5) ===')
optimal_ph = df[df['Soil_pH'].between(6.0, 6.5)]
print(optimal_ph[['Farm_ID', 'Soil_pH', 'Yield_tons']])
# Out:
# === OPTIMAL SOIL pH (6.0 to 6.5) ===
#   Farm_ID  Soil_pH  Yield_tons
# 0    F001      6.5         180
# 2    F003      6.2         416
# 5    F006      6.1         390
# 6    F007      6.4         195

# %%
print('\n=== COMPLEX QUERY: Good conditions ===')
min_rainfall = 600
good_conditions = df.query('Rainfall_mm > @min_rainfall and Fertilizer_kg > 150')
print(good_conditions[['Farm_ID', 'Crop', 'Rainfall_mm', 'Fertilizer_kg']])
# Out:
# === COMPLEX QUERY: Good conditions ===
#   Farm_ID  Crop  Rainfall_mm  Fertilizer_kg
# 2    F003  Corn          680            200
# 4    F005  Rice          850            160
# 5    F006  Corn          710            195

# %%
print('\n=== FIRST 3 FARMS (iloc) ===')
print(df.iloc[0:3])
# Out:
# === FIRST 3 FARMS (iloc) ===
#   Farm_ID   Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH  \
# 0    F001  Wheat         180          450            120      6.5
# 1    F002   Rice         228          820            150      5.8
# 2    F003   Corn         416          680            200      6.2
#
#    Yield_per_ha
# 0           3.6
# 1           4.6
# 2           8.3

# %%
#labels
print('\n=== SPECIFIC COLUMN(loc)===')
print(df.loc[:,['Farm_ID','Crop','Yield_per_ha']])
# Out:
# === SPECIFIC COLUMN(loc)===
#   Farm_ID   Crop  Yield_per_ha
# 0    F001  Wheat           3.6
# 1    F002   Rice           4.6
# 2    F003   Corn           8.3
# 3    F004  Wheat           3.3
# 4    F005   Rice           4.9
# 5    F006   Corn           7.8
# 6    F007  Wheat           3.9

# %%
print('\n===TOP PERFORMERS-SELECTED COLOUMNS===')
top = df[df['Yield_per_ha']>4.5][['Farm_ID','Crop','Yield_per_ha']]
print(top)
# Out:
# ===TOP PERFORMERS-SELECTED COLOUMNS===
#   Farm_ID  Crop  Yield_per_ha
# 1    F002  Rice           4.6
# 2    F003  Corn           8.3
# 4    F005  Rice           4.9
# 5    F006  Corn           7.8

# %%
print('/n===SPECIFIC COLUMNSi(LOC===)')
print(df.loc[:,['farm_id','crop','yield_per_ha']])
# Out:
# /n===SPECIFIC COLUMNSi(LOC===)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2700127690.py in <cell line: 0>()
#       1 print('/n===SPECIFIC COLUMNSi(LOC===)')
# ----> 2 print(df.loc[:,['farm_id','crop','yield_per_ha']])
#
# NameError: name 'df' is not defined
