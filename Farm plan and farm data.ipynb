# %%
farm_data=[
    [1,"rice",45],
    [2,"wheat",30],
    [3,"maize",50]
]
print(farm_data)
print(farm_data[0])
print(farm_data[0][1])
# Out:
# [[1, 'rice', 45], [2, 'wheat', 30], [3, 'maize', 50]]
# [1, 'rice', 45]
# rice

# %%
yield_data=[
    ["rice",2355],
    ["maize",3435],
    ["jower",7324]
]
for crop in yield_data:
 print(crop[0],"yield:",crop[1],"kg/hectare")
# Out:
# rice yield: 2355 kg/hectare
# maize yield: 3435 kg/hectare
# jower yield: 7324 kg/hectare

# %%
#multi season crop planning
crop_plan=[
    ["kharif",["rice","maize"]],
    ["rabi",["wheat","gram"]],
    ["zaid",["vegtables"]]
]
print(crop_plan[0])
print(crop_plan[1][0])
print(crop_plan[1][0])
# Out:
# ['kharif', ['rice', 'maize']]
# rabi
# rabi

# %%
#daily farm expenses
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
]
print(expenses[0])
for day in expenses:
    print(day[0],"total:",sum(day[1]))
# Out:
# ['day1', [1200, 500, 300]]
# day1 total: 2000
# day2 total: 2500
# day3 total: 1900

# %%
def expenses_made():
    expenses=[]
    number_of_days = int(input("enter the number of days:"))
    for i in range(number_of_days):
        day_name=input(f"enter the day name:")
        seed_cost=int(input("enter the seed cost:"))
        fertilizer_cost=int(input("enter the fertilizer cost:"))
        labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
    return expenses
total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
 print(expenditure[0],"expenses are",expenditure[1])
# Out:
# enter the number of days:1
# enter the day name:day1
# enter the seed cost:4326
# enter the fertilizer cost:7689
# enter the labour cost:5432
# daily expenses
# day1 expenses are [4326, 7689, 5432]
