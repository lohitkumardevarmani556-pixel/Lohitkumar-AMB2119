# %%
print("rice".upper())
print("WHEAT".lower())
print("greengram".title())
print("cotton".capitalize())
# Out:
# RICE
# wheat
# Greengram
# Cotton

# %%
#Searching and counting sub stings
text = "organic rice and rice culiivation"
print(text.count("rice"))
print(text.count("rice"))
print("rice" in text)
# Out:
# 2
# 2
# True

# %%
#codes
codes = [
    "CRP_RICE_2024",
    "CRP_WHEAT_2025",
    "FRI_MANGO_2029",
    "CRP_MAIZE_2028"
]
print(codes)
# Out:
# ['CRP_RICE_2024', 'CRP_WHEAT_2025', 'FRI_MANGO_2029', 'CRP_MAIZE_2028']

# %%
#clean codes
clean_codes = []
for code in codes:
    clean_code = code.replace("CRP_", "")
    clean_codes.append(clean_code[4:])
print(clean_codes)
# Out:
# ['_2024', 'T_2025', 'MANGO_2029', 'E_2028']

# %%
from re import split
#spectting class
codes = [
    "CRP_RICE_2024",
    "CRP_WHEAT_2025",
    "FRI_MANGO_2029",
    "CRP_MAIZE_2028"
]
for crops_code in codes:
    crop_name = crops_code.split("_")[1]
    print(crop_name)
# Out:
# RICE
# WHEAT
# MANGO
# MAIZE

# %%
#multiple starting operrators
raw_crops = "rice,12200,Black soil**"
clean_crops = raw_crops.split(",")
crop = clean_crops[0].title()
print(f"crop: {crop}")
# Out:
# crop: Rice

# %%
crop_name = "groundnut"
print(crop_name[0])
print(crop_name[-1])
print(crop_name[4])
print(crop_name[4:])
# Out:
# g
# t
# n
# ndnut
