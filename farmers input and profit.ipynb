# %%
print("======farmer input based profit analysis=====")

seed_cost=float(input("enter seed cost(INR):"))
fertilizer_cost=float(input("ente fertilizer cost(INR):"))
pesticide_cost=float(input("enter pesticide cost(INR):"))
labour_cost=float(input("enter labour cost(INR):"))
irrigation_cost=float(input("enter irrigation cost(INR):"))

total_input_cost=seed_cost+fertilizer_cost+pesticide_cost+labour_cost+irrigation_cost

print("\nTotal cost(INR):",total_input_cost)

total_yeild_kg=float(input("enter total crop yeild(KG):"))
price_per_kg=float(input("enter price per kg(NR):"))
total_revenue=total_yeild_kg*price_per_kg

print("\ntotal revenue:",total_revenue)

profit=total_revenue-total_input_cost

print("\nnet profit/loss:",profit)

profit_per_kg=profit/total_yeild_kg

print("\nprofit per kg:",profit_per_kg)


total_seed_kg=float(input("enter total seed available:"))
see2d_bag_capacity=float(input("enter seed bag capacity"))
full_seed_bags=total_seed_kg//seed_bag_capacity
remaining_seed_kg=total_seed_kg % seed_bag_capacity

print("full seed bags used:",full_seed_bags)
print("remainig seed:",remaining_seed_kg)

initial_crop_units=float(input("enter initial crop units:"))
growth_rate=float(input("enter seasonal growth rate:"))
seasons=int(input("enter number of seasons: "))
expected_crop=initial_crop_units*(growth_rate**seasons)


print("expected crop after seasons:",expected_crop)

weather_loss=float(input("enter loss due to weather:"))
weather_loss=-weather_loss

adjusted_profit=profit-weather_loss

print("Adjusted profut:",adjusted_profit)
# Out:
# ======farmer input based profit analysis=====
